# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
#other useful imports 
import os
import numpy as np
import scipy as sp
import scipy.stats as stats
import h5py

# %%
ls /mnt/data3/yamins/skdata_home/edward_data
# Out:
# InstEval.csv

# %%
import pandas as pd   #this is a python package for tabular data handling
from observations import insteval

#loading the data from csv
data_path = os.path.join(os.environ["SKDATA_ROOT"], "edward_data")
data, metadata = insteval(data_path)

#putting the data into pandas
data = pd.DataFrame(data, columns=metadata['columns'])

# %%
data
# Out:
#           s     d  studage  lectage  service  dept  y
# 0         1  1002        2        2        0     2  5
# 1         1  1050        2        1        1     6  2
# 2         1  1582        2        2        0     2  5
# 3         1  2050        2        2        1     3  3
# 4         2   115        2        1        0     5  2
# 5         2   756        2        1        0     5  4
# 6         3     7        2        1        1    11  4
# 7         3    13        2        1        0    10  5
# 8         3    36        2        1        0    10  5
# 9         3   140        2        1        0    10  4
# 10        3   409        2        2        0    10  4
# 11        3   444        2        2        0    10  4
# 12        3   494        2        1        1     9  4
# 13        3   625        2        2        0    10  3
# 14        3   696        2        2        1     9  2
# 15        3  1056        2        2        1     8  4
# 16        3  1437        2        1        0    10  4
# 17        3  1917        2        1        0    10  5
# 18        3  1936        2        1        0    10  2
# 19        3  2058        2        1        0    10  3
# 20        4    17        2        2        0     2  4
# 21        4    70        2        1        1    11  5
# 22        4   501        2        1        0     2  5
# 23        4  1161        2        1        1    11  3
# 24        4  1323        2        1        0     2  4
# 25        4  1349        2        2        0     2  5
# 26        4  1361        2        1        0     2  4
# 27        4  1564        2        2        0     2  3
# 28        5   115        2        1        0     5  4
# 29        5   536        2        1        0     5  4
# ...     ...   ...      ...      ...      ...   ... ..
# 73391  2972    65        4        5        1     2  3
# 73392  2972    67        4        2        1     4  5
# 73393  2972   110        4        1        1     3  4
# 73394  2972   140        4        2        0    10  3
# 73395  2972   150        4        1        1     8  3
# 73396  2972   273        4        3        0    10  2
# 73397  2972   309        4        3        0    10  4
# 73398  2972   369        4        1        1     6  3
# 73399  2972   377        4        4        0    10  4
# 73400  2972   429        4        1        0    10  1
# 73401  2972   466        4        3        0    10  5
# 73402  2972   494        4        3        1     9  3
# 73403  2972   507        4        6        1    11  2
# 73404  2972   696        4        4        1     9  2
# 73405  2972   714        4        4        1     7  2
# 73406  2972   790        4        5        1    11  3
# 73407  2972   856        4        6        1     9  2
# 73408  2972   916        4        1        1     4  2
# 73409  2972  1056        4        2        1     8  5
# 73410  2972  1106        4        1        1     4  3
# 73411  2972  1203        4        3        1     3  5
# 73412  2972  1722        4        5        1    11  5
# 73413  2972  1749        4        1        0    10  5
# 73414  2972  1780        4        4        1    11  3
# 73415  2972  1782        4        4        1     4  5
# 73416  2972  2034        4        1        1     6  3
# 73417  2972  2079        4        3        1    11  4
# 73418  2972  2084        4        1        0    10  5
# 73419  2972  2110        4        2        1     4  1
# 73420  2972  2121        4        2        1     2  3
#
# [73421 rows x 7 columns]

# %%
import rpy2.robjects as robjects

# %%
dir(robjects)
# Out:
# ['Array',
#  'BoolVector',
#  'ComplexVector',
#  'DataFrame',
#  'DateVector',
#  'Environment',
#  'FactorVector',
#  'FloatVector',
#  'Formula',
#  'Function',
#  'IntVector',
#  'ListVector',
#  'Matrix',
#  'NA_Character',
#  'NA_Complex',
#  'NA_Integer',
#  'NA_Logical',
#  'NA_Real',
#  'NULL',
#  'POSIXct',
#  'POSIXlt',
#  'ParsedCode',
#  'R',
#  'RObject',
#  'RObjectMixin',
#  'RS4',
#  'Sexp',
#  'SexpClosure',
#  'SexpEnvironment',
#  'SexpExtPtr',
#  'SexpS4',
#  'SexpVector',
#  'SignatureTranslatedFunction',
#  'SourceCode',
#  'StrSexpVector',
#  'StrVector',
#  'TYPEORDER',
#  'Vector',
#  '_',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '_function_to_ri',
#  '_globalenv',
#  '_reval',
#  '_rparse',
#  'array',
#  'baseenv',
#  'constants',
#  'conversion',
#  'datetime',
#  'default_converter',
#  'default_py2ri',
#  'emptyenv',
#  'environments',
#  'functions',
#  'globalenv',
#  'help',
#  'int2ri',
#  'itertools',
#  'lib',
#  'methods',
#  'numpy2ri',
#  'os',
#  'packages',
#  'packages_utils',
#  'pandas2ri',
#  'py3bytes',
#  'py3str',
#  'r',
#  'reval',
#  'rinterface',
#  'rlc',
#  'robject',
#  'sequence_to_vector',
#  'sexpvector_to_ro',
#  'sys',
#  'types',
#  'vectors',
#  'zip']

# %%
#to let rpy2 know that you want it to interpret "data" inputs from python
#to R in the "pandas" form
from rpy2.robjects import r, pandas2ri
pandas2ri.activate()

# %%
resid = robjects.r['resid']

# %%
resid
# Out:
# R object with classes: ('function',) mapped to:
# <SignatureTranslatedFunction - Python:0x7f8e79173878 / R:0x82f2218>

# %%
lm = robjects.r['lm']

# %%
lm
# Out:
# R object with classes: ('function',) mapped to:
# <SignatureTranslatedFunction - Python:0x7f8e7badf680 / R:0x82f1458>

# %%
m = lm(formula='y ~ 1 + service', data=data)

# %%
#how to access data about the trained R model in python
np.asarray(m[0])
# Out:
# array([ 3.26223642, -0.13049933])

# %%
resid_vec.shape
# Out:
# (73421,)

# %%
#train the model
m = lm(formula='y ~ 1 + service', data=data)
#call the residual function on the trained model 
resid_vec = np.asarray(resid(m))

plt.hist(resid_vec, bins=20);
plt.title('Residual variance: %.4f' % resid_vec.var())

# %%
m_more = lm(formula='y ~ 1 + service + d', data=data)
resid_vec_more = np.asarray(resid(m_more))
plt.hist(resid_vec_more);
plt.title('Residual variance: %.4f' % resid_vec_more.var())

# %%
m_all = lm(formula='y ~ 1 + d + dept + s + service', data=data)
resid_vec_all = np.asarray(resid(m_all))
plt.hist(resid_vec_all);
plt.title('Residual variance: %.4f' % resid_vec_all.var())

# %%
from rpy2.robjects.packages import importr
lme4 = importr('lme4')

# %%
lme4
# Out:
# rpy2.robjects.packages.Package as a <module 'lme4' (built-in)>

# %%
dir(lme4)
# Out:
# ['Cv_to_Sv',
#  'Cv_to_Vv',
#  'Eigen_SSE',
#  'GHrule',
#  'GQN',
#  'GQdk',
#  'Gamma_simfun',
#  'NelderMead',
#  'NelderMead_Create',
#  'NelderMead_newf',
#  'NelderMead_setForce_stop',
#  'NelderMead_setFtol_abs',
#  'NelderMead_setFtol_rel',
#  'NelderMead_setIprint',
#  'NelderMead_setMaxeval',
#  'NelderMead_setMinf_max',
#  'NelderMead_value',
#  'NelderMead_xeval',
#  'NelderMead_xpos',
#  'Nelder_Mead',
#  'REMLcrit',
#  'RHSForm',
#  'RHSForm<-',
#  'RglmerWrkIter',
#  'Sv_to_Cv',
#  'VarCorr_merMod',
#  'Vv_to_Cv',
#  '_S3MethodsClasses',
#  '___C__NelderMead',
#  '___C__family',
#  '___C__glmFamily',
#  '___C__glmResp',
#  '___C__glmerMod',
#  '___C__golden',
#  '___C__lmList4',
#  '___C__lmList4_confint',
#  '___C__lmResp',
#  '___C__lmerMod',
#  '___C__lmerResp',
#  '___C__merMod',
#  '___C__merPredD',
#  '___C__nlmerMod',
#  '___C__nlsResp',
#  '___C__rePos',
#  '___C__vcRep',
#  '___NAMESPACE___',
#  '___S3MethodsTable___',
#  '___T__getL:lme4',
#  '___T__show:methods',
#  '___global__',
#  '___suppressForeign__',
#  '__doc__',
#  '__name__',
#  '__rdata__',
#  '__rname__',
#  '__version__',
#  '_env',
#  '_exported_names',
#  '_get_checkingOpts',
#  '_hasScale',
#  '_isDiagonal_sq_matrix',
#  '_makeCC',
#  '_merMod_msgs',
#  '_minimalOptinfo',
#  '_modelMatrixDrop',
#  '_ns_lme4',
#  '_ns_nlme',
#  '_onLoad',
#  '_onUnload',
#  '_optinfo',
#  '_packageName',
#  '_prt_VC',
#  '_prt_aictab',
#  '_prt_call',
#  '_prt_family',
#  '_prt_grps',
#  '_prt_methTit',
#  '_prt_resids',
#  '_prt_warn',
#  '_requireCachedGenerics',
#  '_rpy2r',
#  '_simpleCap',
#  '_simulateFun',
#  '_symbol_check_after',
#  '_symbol_r2python',
#  '_translation',
#  'abbrDeparse',
#  'ad',
#  'all0',
#  'allPerm_int',
#  'allVarsRec',
#  'anovaLmer',
#  'anova_merMod',
#  'anyBars',
#  'asDf0',
#  'asOneFormula',
#  'as_data_frame_VarCorr_merMod',
#  'as_data_frame_boot',
#  'as_data_frame_ranef_mer',
#  'as_data_frame_thpr',
#  'as_function_merMod',
#  'barnames',
#  'binomial_simfun',
#  'bootMer',
#  'c_deparse',
#  'cat_f',
#  'chck1',
#  'checkArgs',
#  'checkConv',
#  'checkCtrlLevels',
#  'checkFormulaData',
#  'checkHess',
#  'checkNlevels',
#  'checkResponse',
#  'checkScaleX',
#  'checkZdims',
#  'checkZrank',
#  'check_boundary',
#  'chkRank_drop_cols',
#  'chk_cconv',
#  'chk_convOpt',
#  'chooseFace',
#  'coefMer',
#  'coef_lmList4',
#  'coef_merMod',
#  'condVar',
#  'confint_lmList4',
#  'confint_merMod',
#  'confint_thpr',
#  'cont',
#  'cov2sdcor',
#  'deepcopy',
#  'dens',
#  'densityplot_thpr',
#  'deriv12',
#  'devCrit',
#  'devcomp',
#  'devfun2',
#  'deviance_merMod',
#  'df_residual_merMod',
#  'dim_merMod',
#  'doCheck',
#  'dotplot_coef_mer',
#  'dotplot_ranef_mer',
#  'drop1_merMod',
#  'dropOffset',
#  'dummy',
#  'est_theta',
#  'expandDoubleVerts',
#  'extractAIC_merMod',
#  'factorize',
#  'family2char',
#  'family_glmResp',
#  'family_lmResp',
#  'family_merMod',
#  'family_nlsResp',
#  'famlink',
#  'fgq_rules',
#  'findbars',
#  'fitted_lmList4',
#  'fitted_merMod',
#  'fixed_effects',
#  'fixef_lmList4',
#  'fixef_merMod',
#  'forceCopy',
#  'formatVC',
#  'format_perc',
#  'formula_lmList4',
#  'formula_merMod',
#  'fortify',
#  'fortify_merMod',
#  'gamma_shape_merMod',
#  'gaussian_simfun',
#  'getConv',
#  'getCovariateFormula',
#  'getData',
#  'getFixedFormula',
#  'getGroupsFormula',
#  'getGroupsFormula_default',
#  'getGroupsFormula_merMod',
#  'getGroups_lmList4',
#  'getIDLabels',
#  'getL',
#  'getME',
#  'getME_merMod',
#  'getNBdisp',
#  'getOptfun',
#  'getResponseFormula',
#  'getStart',
#  'get_clen',
#  'get_orig_levs',
#  'get_which',
#  'glFormula',
#  'glmFamily',
#  'glmFamily_Create',
#  'glmFamily_aic',
#  'glmFamily_devResid',
#  'glmFamily_link',
#  'glmFamily_linkInv',
#  'glmFamily_muEta',
#  'glmFamily_setTheta',
#  'glmFamily_theta',
#  'glmFamily_variance',
#  'glmNB_to_change',
#  'glmResp',
#  'glmResp_f_nms',
#  'glm_Create',
#  'glm_Laplace',
#  'glm_aic',
#  'glm_devResid',
#  'glm_family',
#  'glm_link',
#  'glm_muEta',
#  'glm_resDev',
#  'glm_setN',
#  'glm_setTheta',
#  'glm_sqrtWrkWt',
#  'glm_theta',
#  'glm_updateMu',
#  'glm_updateWts',
#  'glm_variance',
#  'glm_wrkResids',
#  'glm_wrkResp',
#  'glm_wtWrkResp',
#  'glmer',
#  'glmerAGQ',
#  'glmerControl',
#  'glmerLaplace',
#  'glmerLaplaceHandle',
#  'glmerPwrssUpdate',
#  'glmer_nb',
#  'golden',
#  'golden_Create',
#  'golden_newf',
#  'golden_value',
#  'golden_xeval',
#  'golden_xpos',
#  'grad_ctr',
#  'grad_ctr2',
#  'grad_ctr3',
#  'grad_ctr4',
#  'gradient',
#  'grpfact',
#  'gsummary',
#  'hasNoScale',
#  'hasScale',
#  'hatvalues_merMod',
#  'hessian',
#  'isAnyArgBar',
#  'isBar',
#  'isFlexLambda',
#  'isGLMM',
#  'isGLMM_merMod',
#  'isGLMlist',
#  'isLMM',
#  'isLMM_merMod',
#  'isNBfamily',
#  'isNLMM',
#  'isNLMM_merMod',
#  'isNested',
#  'isNullExtPtr',
#  'isREML',
#  'isREML_merMod',
#  'lFormula',
#  'levelfun',
#  'llikAIC',
#  'lmList',
#  'lmResp',
#  'lm_Create',
#  'lm_setOffset',
#  'lm_setResp',
#  'lm_setWeights',
#  'lm_updateMu',
#  'lm_wrss',
#  'lmer',
#  'lmerControl',
#  'lmerResp',
#  'lmer_Create',
#  'lmer_Deviance',
#  'lmer_Laplace',
#  'lmer_opt1',
#  'lmer_setREML',
#  'logLik_lmList4',
#  'logLik_merMod',
#  'logProf',
#  'log_thpr',
#  'makeFac',
#  'mcmcsamp',
#  'merPredD',
#  'merPredDCcNumer',
#  'merPredDCreate',
#  'merPredDL',
#  'merPredDPvec',
#  'merPredDRX',
#  'merPredDRXdiag',
#  'merPredDRXi',
#  'merPredDb',
#  'merPredDbeta',
#  'merPredDcondVar',
#  'merPredDinstallPars',
#  'merPredDldL2',
#  'merPredDldRX2',
#  'merPredDlinPred',
#  'merPredDsetBeta0',
#  'merPredDsetDelb',
#  'merPredDsetDelu',
#  'merPredDsetTheta',
#  'merPredDsetZt',
#  'merPredDsolve',
#  'merPredDsolveU',
#  'merPredDsqrL',
#  'merPredDu',
#  'merPredDunsc',
#  'merPredDupdateDecomp',
#  'merPredDupdateL',
#  'merPredDupdateLamtUt',
#  'merPredDupdateRes',
#  'merPredDupdateXwts',
#  'meth',
#  'methTitle',
#  'missDataFun',
#  'mkBlist',
#  'mkDataTemplate',
#  'mkGlmerDevfun',
#  'mkLmerDevfun',
#  'mkMerMod',
#  'mkMinimalData',
#  'mkNewReTrms',
#  'mkParsTemplate',
#  'mkPfun',
#  'mkReTrms',
#  'mkRespMod',
#  'mkVarCorr',
#  'mkdevfun',
#  'mlist2vec',
#  'mmList',
#  'mmList_formula',
#  'mmList_merMod',
#  'modelFormula',
#  'model_frame_merMod',
#  'model_matrix_merMod',
#  'mygrad',
#  'namedList',
#  'negative_binomial_simfun',
#  'ngrps',
#  'ngrps_default',
#  'ngrps_factor',
#  'ngrps_merMod',
#  'nlformula',
#  'nlmer',
#  'nlmerControl',
#  'nlmerLaplace',
#  'nlminbwrap',
#  'nloptwrap',
#  'nlsResp',
#  'nls_Create',
#  'nls_Laplace',
#  'nls_updateMu',
#  'noLHSform',
#  'noReForm',
#  'nobars',
#  'nobars_',
#  'nobs_merMod',
#  'normalizeFamilyName',
#  'npar_merMod',
#  'optTheta',
#  'optimizeGlmer',
#  'optimizeLmer',
#  'optwrap',
#  'pairs_lmList4',
#  'panel_thpr',
#  'plot_coef_mer',
#  'plot_lmList4',
#  'plot_lmList4_confint',
#  'plot_merMod',
#  'plot_ranef_mer',
#  'plot_summary_mer',
#  'poisson_simfun',
#  'pooledSD',
#  'predict_lmList4',
#  'predict_merMod',
#  'predy',
#  'print_VarCorr_merMod',
#  'print_merMod',
#  'print_ranef_mer',
#  'print_summary_merMod',
#  'profile_merMod',
#  'profnames',
#  'qqmath_merMod',
#  'qqmath_ranef_mer',
#  'qqnorm_lmList4',
#  'quickSimulate',
#  'random_effects',
#  'ranef_lmList4',
#  'ranef_merMod',
#  'reFormHack',
#  'reOnly',
#  'rePos',
#  'reexpr',
#  'refit',
#  'refit2_merMod',
#  'refitML',
#  'refitML_merMod',
#  'refitNB',
#  'refit_merMod',
#  'residuals_glmResp',
#  'residuals_lmList4',
#  'residuals_lmResp',
#  'residuals_merMod',
#  'sacos',
#  'safeDeparse',
#  'safe_chol',
#  'safe_pchisq',
#  'sdcor2cov',
#  'setNBdisp',
#  'setNullExtPtr',
#  'setParams',
#  'showlocation',
#  'sigma',
#  'sigma_lmList4',
#  'sigma_merMod',
#  'simfunList',
#  'simulate_formula',
#  'simulate_merMod',
#  'splitFormula',
#  'splom_thpr',
#  'stripExpr',
#  'subbars',
#  'subnms',
#  'summary_lmList4',
#  'summary_merMod',
#  'summary_summary_merMod',
#  'tauij',
#  'termnms',
#  'terms_merMod',
#  'testLevel',
#  'tnames',
#  'updateGlmerDevfun',
#  'updateStart',
#  'update_lmList4',
#  'update_merMod',
#  'varianceProf',
#  'vcRep',
#  'vcov_merMod',
#  'vcov_summary_merMod',
#  'vec2STlist',
#  'vec2mlist',
#  'warnErrList',
#  'weights_merMod',
#  'wmsg',
#  'xyplot_thpr']

# %%
lme4.lmer
# Out:
# R object with classes: ('function',) mapped to:
# <DocumentedSTFunction - Python:0x7f8e79bb2f38 / R:0x84ebd30>

# %%
lme4.lmer.__rname__
# Out:
# 'lmer'

# %%
m1 = lme4.lmer(formula='y ~ 1 + service + (1|s) + (1|d) + (1|dept)', data=data)
resid_vec1 = np.asarray(resid(m1))
plt.hist(resid_vec1);
plt.title('Residual variance: %.4f' % resid_vec1.var())

# %%
m2 = lme4.lmer(formula='y ~ 1 + service + (1|dept) + (1|d)', data=data)
resid_vec2 = np.asarray(resid(m2))
plt.hist(resid_vec2);
plt.title('Residual variance: %.4f' % resid_vec2.var())

# %%
m3 = lme4.lmer(formula='y ~ 1 + service + (1|d)', data=data)
resid_vec3 = np.asarray(resid(m3))
plt.hist(resid_vec3);
plt.title('Residual variance: %.4f' % resid_vec3.var())

# %%
m4 = lme4.lmer(formula='y ~ 1 + service + (1|s)', data=data)
resid_vec4 = np.asarray(resid(m4))
plt.hist(resid_vec4);
plt.title('Residual variance: %.4f' % resid_vec4.var())

# %%
m5 = lme4.lmer(formula='y ~ 1 + service + (1|s) + (1|dept)', data=data)
resid_vec5 = np.asarray(resid(m5))
plt.hist(resid_vec5);
plt.title('Residual variance: %.4f' % resid_vec5.var())

# %%
m6 = lme4.lmer(formula='y ~ 1 + (1|d)', data=data)
resid_vec6 = np.asarray(resid(m6))
plt.hist(resid_vec6);
plt.title('Residual variance: %.4f' % resid_vec6.var())

# %%
plt.hist(resid_vec1,bins=100);
plt.hist(resid_vec6,bins=100, alpha=.8);

# %%
#ok let's load our usual data 
DATA_PATH = "/home/chengxuz/Class/psych253_2018/data/ventral_neural_data.hdf5"
Ventral_Dataset = h5py.File(DATA_PATH)

# %%
Neural_Data = Ventral_Dataset['time_averaged_trial_averaged'][:]
IT_NEURONS = Ventral_Dataset['neural_meta']['IT_NEURONS']
V4_NEURONS = Ventral_Dataset['neural_meta']['V4_NEURONS']
V4_Neural_Data = Neural_Data[:, V4_NEURONS]
IT_Neural_Data = Neural_Data[:, IT_NEURONS]

var_level = Ventral_Dataset['image_meta']['variation_level'][:]
categories = Ventral_Dataset['image_meta']['category'][:]   #array of category labels for all images  --> shape == (5760,)
unique_categories = np.unique(categories)                #array of unique category labels --> shape == (8,)
objects = Ventral_Dataset['image_meta']['object_name'][:]   #array of object labels for all images --> shape == (5670,)
unique_objects = np.unique(objects)                      #array of unique object labels --> shape == (64,) 

objects_by_category = {c: np.unique(objects[categories == c]) 
                       for c in unique_categories}

# %%
#use numpy recarray object to store metadata 
meta_array = np.core.records.fromarrays(Ventral_Dataset['image_meta'].values(),
                                        names=Ventral_Dataset['image_meta'].keys())
meta_array.dtype
# Out:
# dtype((numpy.record, [(u'category', 'S7'), (u'image_id', 'S40'), (u'object_name', 'S24'), (u'rotation_xy', '<f8'), (u'rotation_xz', '<f8'), (u'rotation_yz', '<f8'), (u'size', '<f8'), (u'translation_y', '<f8'), (u'translation_z', '<f8'), (u'variation_level', 'S2')]))

# %%
data_dict = {'n%d' % d : Neural_Data[:, d] for d in range(Neural_Data.shape[1])}
data_dict.update({k: meta_array[k] for k in meta_array.dtype.names})

neural_data_frame = pandas.DataFrame.from_dict(data_dict)

# %%
data_dict['n32'].shape
# Out:
# (5760,)

# %%
neural_data_frame
# Out:
#      category                                  image_id        n0        n1  \
# 0      Fruits  f1ae7c2160c6cbb309b940a0dc127a8aa1060e5d -0.081081 -0.209962
# 1      Fruits  691384450355c07ad084613a08a018ae8e1eebb2 -0.363256 -0.568020
# 2      Fruits  fe9cd029e43ebdeeb509b61db1573a8286d06e6a  0.253764  0.045827
# 3      Fruits  c766632574f6d86f0a048f2e5817826c1888699b -0.247957 -0.086242
# 4      Fruits  7edd311b0ef7a9e61c62c6cbc2b3cfc2b5b6ea9d -0.127980  0.430337
# 5      Fruits  3a2e8aeaae50f81d1d4fc716969bd2c8e169b9d9  0.395413 -0.002292
# 6      Fruits  5cde85cc63e677623c606ebf6d21a6b028b50baf  0.001503 -0.050838
# 7      Fruits  7cc53b502f4edb4c80316733868a33894016aa53 -0.394901  0.296192
# 8      Fruits  c01fd13e140ad955d7ce56c365f6c0d850c0abbb -0.250520  0.178697
# 9      Fruits  202e13540b85d535b6fcabe430647ec11dcc67a5 -0.124786 -0.171695
# 10     Fruits  97d2757946971047f406eb562e947cce75e1d1e3 -0.057379  0.115677
# 11     Fruits  6e2ddadd2ca093f7638282e4851b60d5b87b8ca4 -0.002541  0.136466
# 12     Fruits  b54f9e7fbc9f49bb60f6d24aa9e90b7623a4b42d -0.020599 -0.098620
# 13     Fruits  eb5533e147d78342f664e4f3f1968a62ada7acb9 -0.237810 -0.505942
# 14     Fruits  ac2ca681980fce7d038b837b6b3bdf1db72bd440  0.303198  0.093211
# 15     Fruits  3dce823bb638b1a29eeb116c2f924bfcaaff60ff  0.129096 -0.281774
# 16     Fruits  ae2b8aac003c867a772647197dcd3c050b75a06e -0.170282  0.154614
# 17     Fruits  a38eaebb855209eaf96ddc35f27bd35fe2c8f0ae -0.154096 -0.192668
# 18     Fruits  4c4a223b8642ff7c80db97a660ac37ada8cba732  0.023848 -0.099189
# 19     Fruits  f6192eed74846a86733c12b2400459b7b3dff1b6 -0.120167  0.042496
# 20      Boats  c067441bed74bbdb4912282e908c839732c738bc -0.055438  0.527070
# 21      Boats  2b9cc6ae0ad72f512bd84cca2f724952b03ba54e  0.410650  0.106542
# 22      Boats  afb7c387453bace279dbdf9e06c40ea39624768a  0.008356  0.091862
# 23      Boats  b840cfe74dbc13fd6c85316f1bb6edae58dd0ebb  0.045853  0.320136
# 24      Boats  38887fb925862873f9320d3b8964f7c5f57db134 -0.207809 -0.062486
# 25      Boats  5f4ea554c5cf965520a54fbb0a18fcee3931c954 -0.017131 -0.338816
# 26      Boats  d34f62684363e54513b830dd9192aaa18c5c8651 -0.284291 -0.018372
# 27      Boats  be5888d2cbe8ce06fa6d35a13eb9a58149c0b784 -0.005665 -0.122723
# 26          0.000       -0.000  1.42000          0.000          0.000
# 27          0.000       -0.000  1.42000          0.000          0.000
# 28          0.000       -0.000  1.42000          0.000          0.000
# 29          0.000       -0.000  1.42000          0.000          0.000
# ...           ...          ...      ...            ...            ...
# 5730       64.885       -2.787  1.84316         -0.553          0.113
# 5731       65.932      -43.622  1.41600         -0.356          0.595
# 5732       68.439      -72.142  1.67442         -0.165          0.450
# 5733       69.157       -8.823  1.45140         -0.568         -0.860
# 5734       73.886       75.404  0.79178          0.022          1.033
# 5735       77.115      -82.655  1.69684          0.049         -0.871
# 5736       80.452       77.849  0.88146          0.580         -1.192
# 5737       89.560       77.975  0.74694          0.546         -0.520
# 5738       -3.998      -67.726  1.39712         -0.411         -0.907
# 5739       -9.929       30.773  1.20950         -0.483          0.457
# 5740      -13.186      -24.282  0.81302          0.551         -0.574
# 5741      -16.080       -2.610  0.92276         -0.138         -1.084
# 5742      -19.952       27.868  1.39358          0.225          0.028
# 5743      -20.279      -87.580  1.04902         -0.522         -0.422
# 5744      -23.153       18.413  0.99356         -0.408          0.835
# 5745      -28.337       57.500  1.60952         -0.464         -0.972
# 5746      -38.736       65.502  1.68504          0.312          0.042
# 5747      -49.160       -0.264  1.83490         -0.277         -0.830
# 5748      -52.935       -0.592  1.00772          0.576          0.028
# 5749      -54.264       11.103  1.84906         -0.391         -0.960
# 5750      -54.823       84.744  1.11746         -0.103          0.082
# 5751      -63.740      -73.545  1.76528         -0.411          0.422
# 5752      -68.594       75.781  0.76110          0.311          0.961
# 5753      -69.853       72.695  1.65436         -0.043          0.072
# 5754      -71.912      -31.938  1.30154          0.571         -0.603
# 5755      -78.281       66.625  1.18000          0.125         -0.770
# 5756      -85.608      -87.242  1.78770         -0.194         -0.077
# 5757      -86.072       38.988  1.64492         -0.283          0.244
# 5758      -86.882       51.389  1.22602         -0.014          0.402
# 5759      -87.958       79.689  1.03250          0.145         -0.072
#
#       variation_level
# 0                  V0
# 1                  V0
# 2                  V0
# 3                  V0
# 4                  V0
# 5                  V0
# 6                  V0
# 7                  V0
# 8                  V0
# 9                  V0
# 10                 V0
# 11                 V0
# 12                 V0
# 13                 V0
# 14                 V0
# 15                 V0
# 16                 V0
# 17                 V0
# 18                 V0
# 19                 V0
# 20                 V0
# 21                 V0
# 22                 V0
# 23                 V0
# 24                 V0
# 25                 V0
# 26                 V0
# 27                 V0
# 28                 V0
# 29                 V0
# ...               ...
# 5730               V6
# 5731               V6
# 5732               V6
# 5733               V6
# 5734               V6
# 5735               V6
# 5736               V6
# 5737               V6
# 5738               V6
# 5739               V6
# 5740               V6
# 5741               V6
# 5742               V6
# 5743               V6
# 5744               V6
# 5745               V6
# 5746               V6
# 5747               V6
# 5748               V6
# 5749               V6
# 5750               V6
# 5751               V6
# 5752               V6
# 5753               V6
# 5754               V6
# 5755               V6
# 5756               V6
# 5757               V6
# 5758               V6
# 5759               V6
#
# [5760 rows x 306 columns]

# %%
res = lm(formula='n0 ~ 1 + category', data=neural_data_frame)
resid_vec_res = np.asarray(resid(res))
plt.hist(resid_vec_res);
resid_vec_res.var()
# Out:
# 0.08042158803002887

# %%
#now let's look at a neuron that we *expect* to be categorical
res = lm(formula='n184 ~ 1 + category', data=neural_data_frame)
resid_vec_res = np.asarray(resid(res))
plt.hist(resid_vec_res);
resid_vec_res.var()
# Out:
# 0.032766009456335218

# %%
res
# Out:
# R object with classes: ('lm',) mapped to:
# <ListVector - Python:0x7f8e799a47a0 / R:0xd691290>
# [Float..., Float..., Float..., ..., Vector, Formula, DataF...]
#   coefficients: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x7f8e79978fc8 / R:0x1e9205a0>
# [-0.029444, -0.018860, 0.013143, ..., 0.053717, -0.031061, -0.039967]
#   residuals: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x7f8e799781b8 / R:0x20a50af0>
# [0.190417, 0.015420, -0.217066, ..., 0.084531, -0.106369, -0.019646]
#   effects: <class 'rpy2.robjects.vectors.FloatVector'>
#   R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x7f8e799787a0 / R:0xea55f50>
# [-0.074215, -1.413663, -0.704820, ..., 0.074523, -0.116378, -0.029654]
#   ...
#   coefficients: <class 'rpy2.robjects.vectors.Vector'>
#   R object with classes: ('lm',) mapped to:
# <Vector - Python:0x7f8e79978d88 / R:0xca5f4c0>
# [RNULLType, Vector, Vector]
#   residuals: <class 'rpy2.robjects.Formula'>
#   R object with classes: ('terms', 'formula') mapped to:
# <Formula - Python:0x7f8e79978e18 / R:0x13830fa0>
# R object with classes: ('lm',) mapped to:
# <ListVector - Python:0x7f8e799a47a0 / R:0xd691290>
# [Float..., Float..., Float..., ..., Vector, Formula, DataF...]

# %%
np.asarray(res[0]).shape
# Out:
# (8,)

# %%
np.asarray(res[0])
# Out:
# array([-0.02944394, -0.01885967,  0.01314343, -0.0247192 ,  0.2911198 ,
#         0.05371732, -0.03106055, -0.03996662])

# %%
res = lm(formula='n184 ~ 1 + rotation_xy', data=neural_data_frame)
resid_vec_res = np.asarray(resid(res))
plt.hist(resid_vec_res);
resid_vec_res.var()
# Out:
# 0.04277590536839504

# %%
res = lme4.lmer(formula='n0 ~ 1 + object_name + category + (1|category)', data=neural_data_frame)
resid_vec_res = np.asarray(resid(res))
plt.hist(resid_vec_res);
resid_vec_res.var()
# Out:
# 0.077938275596386372

# %%
resids_lm_simple = np.asarray([resid(lm(formula='n%d ~ 1 + size + translation_y + translation_z +'
                                               'rotation_xy + rotation_yz + rotation_xz' % d, 
                                               data=neural_data_frame)) 
                              for d in range(0, 296, 20)])

# %%
resids_lm_simple.shape
# Out:
# (15, 5760)

# %%
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(resids_lm_simple[0], bins=100);
plt.xlabel('Residuals for neuron 0')
plt.ylabel('image count')
plt.subplot(1, 2, 2)
plt.hist(resids_lm_simple.var(1));
plt.xlabel('residual variance')
plt.ylabel('neuron count')

# %%
resids_lm = np.asarray([resid(lm(formula='n%d ~ 1 + size + translation_y + translation_z +'
                                               'rotation_xy + rotation_yz + rotation_xz + object_name' % d, 
                                               data=neural_data_frame)) 
                              for d in range(0, 296, 20)])

# %%
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(resids_lm[0], bins=100);
plt.xlabel('Residual')
plt.ylabel('image count')
plt.subplot(1, 2, 2)
plt.hist(resids_lm.var(1));
plt.xlabel('residual variance')
plt.ylabel('neuron count')

# %%
resids_lmer_rand_intercept = np.asarray([resid(lme4.lmer(formula='n%d ~ 1 + size + translation_y + translation_z +'
                                                         'rotation_xy + rotation_yz + rotation_xz + ' 
                                                         '(1|object_name)' % d, 
                                          data=neural_data_frame)) for d in range(0, 296, 20)])

# %%
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(resids_lmer_rand_intercept[0], bins=100);
plt.xlabel('Residual')
plt.ylabel('image count')
plt.subplot(1, 2, 2)
plt.hist(resids_lmer_rand_intercept.var(1));
plt.xlabel('residual variance')
plt.ylabel('neuron count')

# %%
resids_lmer_rand_slope = np.asarray([resid(lme4.lmer(formula='n%d ~ size + translation_y + translation_z +'
                                                     'rotation_xy + rotation_yz + rotation_xz +' 
                                          '(1+size+translation_y + translation_z+rotation_xy + rotation_yz + rotation_xz|object_name)' % d, 
                                          data=neural_data_frame)) for d in range(0, 296, 20)])
# Out:
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 4:
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In optwrap(optimizer, devfun, opt$par, lower = rho$lower, control = control,  :
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 5:
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Model failed to converge with max|grad| = 7.48562 (tol = 0.002, component 1)
#
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 6:
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Model is nearly unidentifiable: very large eigenvalue
#  - Rescale variables?
#
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 7:
#   warnings.warn(x, RRuntimeWarning)

# %%
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(resids_lmer_rand_slope[0], bins=100);
plt.xlabel('Residual')
plt.ylabel('image count')
plt.subplot(1, 2, 2)
plt.hist(resids_lmer_rand_slope.var(1));
plt.xlabel('residual variance')
plt.ylabel('neuron count')

# %%
resids_lm_simple.var(axis=1) - resids_lmer_rand_intercept.var(axis=1)
# Out:
# array([ 0.00540252,  0.02095933,  0.00167607,  0.01371456,  0.00604386,
#         0.0009609 ,  0.01562236,  0.01037694,  0.00874247,  0.00662637,
#         0.01357881,  0.01195196,  0.06952596,  0.00112671,  0.        ])

# %%
resids_lm.var(axis=1) - resids_lmer_rand_intercept.var(axis=1)
# Out:
# array([ -1.37731459e-04,  -6.64738365e-04,  -1.53016013e-04,
#         -3.11310943e-05,  -2.21782385e-05,  -1.46442891e-04,
#         -2.78538409e-04,  -1.12552308e-04,  -3.31850009e-04,
#         -5.02159642e-05,  -5.54466402e-05,  -8.71838313e-05,
#         -2.66925478e-05,  -2.10290005e-04,  -3.85231319e-04])

# %%
resids_lm_simple.var(axis=1) - resids_lmer_rand_slope.var(axis=1)
# Out:
# array([ 0.00906039,  0.02673226,  0.00291349,  0.01674122,  0.0078159 ,
#         0.00227965,  0.02320486,  0.01250912,  0.01238066,  0.00702836,
#         0.01784366,  0.0193374 ,  0.08094114,  0.00218804,  0.00056743])

# %%
# Out:
# array([ -1.37731459e-04,  -6.64738365e-04,  -1.53016013e-04,
#         -3.11310943e-05,  -2.21782385e-05,  -1.46442891e-04,
#         -2.78538409e-04,  -1.12552308e-04,  -3.31850009e-04,
#         -5.02159642e-05,  -5.54466402e-05,  -8.71838313e-05,
#         -2.66925478e-05,  -2.10290005e-04,  -3.85231319e-04])

# %%
resids_lm.var(axis=1) - resids_lmer_rand_slope.var(axis=1)
# Out:
# array([ 0.00352015,  0.00510819,  0.0010844 ,  0.00299553,  0.00174985,
#         0.00117231,  0.00730397,  0.00201962,  0.00330634,  0.00035178,
#         0.00420939,  0.00729826,  0.01138849,  0.00085103,  0.0001822 ])
